# %%
import pandas as pd

# %%
# NOTA (confidencialidad): la exportacion operativa de origen es confidencial y NO se versiona.
# Coloca tu archivo local y ajusta la ruta relativa antes de ejecutar.
operaciones = pd.read_csv("data/origen/operaciones_origen.csv", sep=";", encoding="utf-8")

# %%
operaciones.head(1)

# %%
operaciones.to_csv("data/raw/operaciones.csv", encoding="utf-8", index=False)

# %%
# NOTA (confidencialidad): la exportacion de operadores de origen es confidencial y NO se versiona.
usuarios = pd.read_csv("data/origen/operadores_origen.csv", sep=";", encoding="utf-8")

# %%
usuarios.head(2)

# %%
usuarios.to_csv("data/raw/usuarios.csv", encoding="utf-8", index=False)
